# %% [markdown]
# <a href="https://colab.research.google.com/github/CoLaONI/Machine-learning/blob/main/3_2_%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

perch_length = np.array(
    [8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0,
     21.0, 21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5,
     22.5, 22.7, 23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5,
     27.3, 27.5, 27.5, 27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0,
     36.5, 36.0, 37.0, 37.0, 39.0, 39.0, 39.0, 40.0, 40.0, 40.0,
     40.0, 42.0, 43.0, 43.0, 43.5, 44.0]
     )
perch_weight = np.array(
    [5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0,
     110.0, 115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0,
     130.0, 150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0,
     197.0, 218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0,
     514.0, 556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0,
     820.0, 850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0,
     1000.0, 1000.0]
     )

# %%
from sklearn.model_selection import train_test_split


X_train,X_test,y_train, y_test = train_test_split(perch_length, perch_weight, test_size = 0.33, random_state=42)

X_train = X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)

# %%
len(X_train),len(X_test),len(y_train),len(y_test)
# Out:
# (37, 19, 37, 19)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_train,y_train)
# Out:
# 0.9370031970805529

# %%
lr.score(X_test,y_test)
# Out:
# 0.8390932923594099

# %%
lr.coef_, lr.intercept_
# Out:
# (array([39.71213237]), -734.1031106188752)

# %%
import matplotlib.pyplot as plt

plt.scatter(X_train,y_train)
plt.plot([15, 50], [15*lr.coef_+lr.intercept_, 50*lr.coef_+lr.intercept_])
plt.show()

# %%
X_train_poly = np.column_stack((X_train ** 2, X_train))
X_test_poly = np.column_stack((X_test ** 2, X_test))

X_train_poly
# Out:
# array([[ 625.  ,   25.  ],
#        [1600.  ,   40.  ],
#        [1521.  ,   39.  ],
#        [1849.  ,   43.  ],
#        [ 484.  ,   22.  ],
#        [ 400.  ,   20.  ],
#        [ 484.  ,   22.  ],
#        [ 576.  ,   24.  ],
#        [ 756.25,   27.5 ],
#        [1849.  ,   43.  ],
#        [1600.  ,   40.  ],
#        [ 576.  ,   24.  ],
#        [ 441.  ,   21.  ],
#        [ 756.25,   27.5 ],
#        [1600.  ,   40.  ],
#        [1075.84,   32.8 ],
#        [ 702.25,   26.5 ],
#        [1332.25,   36.5 ],
#        [ 187.69,   13.7 ],
#        [ 515.29,   22.7 ],
#        [ 225.  ,   15.  ],
#        [1369.  ,   37.  ],
#        [1225.  ,   35.  ],
#        [ 823.69,   28.7 ],
#        [ 552.25,   23.5 ],
#        [1521.  ,   39.  ],
#        [ 441.  ,   21.  ],
#        [ 529.  ,   23.  ],
#        [ 484.  ,   22.  ],
#        [1936.  ,   44.  ],
#        [ 506.25,   22.5 ],
#        [ 361.  ,   19.  ],
#        [1369.  ,   37.  ],
#        [ 484.  ,   22.  ],
# ...

# %%
point = np.arange(15, 50)

plt.scatter(X_train, y_train)
plt.scatter(X_test, y_test)

plt.plot(point, 1.01*point**2 - 21.27*point + 109.27)

plt.show()
